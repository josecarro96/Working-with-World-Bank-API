# %% [markdown]
# <h1><center><u>life Expentancy, focus on Uruguay</u></center></h1>

# %%
import wbgapi as wb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Obtain Life Expectancy
lifeexp_df_Total = wb.data.DataFrame('SP.DYN.LE00.IN',
                                      labels = True ) #Labels=True muestra el nombre de los países
lifeexp_df_Total
# Out:
#                                 Country     YR1960     YR1961     YR1962  \
# economy
# ZWE                            Zimbabwe  53.019000  53.483000  53.946000
# ZMB                              Zambia  46.687000  47.084000  47.446000
# YEM                         Yemen, Rep.  29.919000  30.163000  30.500000
# PSE                  West Bank and Gaza        NaN        NaN        NaN
# VIR               Virgin Islands (U.S.)  66.224854  66.487976  66.741098
# ...                                 ...        ...        ...        ...
# CEB      Central Europe and the Baltics  67.821389  68.262198  68.006926
# CSS              Caribbean small states  62.746306  63.126130  63.476453
# ARB                          Arab World  46.546909  47.141620  47.731782
# AFW          Africa Western and Central  37.205380  37.632546  38.052612
# AFE         Africa Eastern and Southern  42.716053  43.166935  43.603990
#
#             YR1963     YR1964     YR1965     YR1966     YR1967     YR1968  \
# ...

# %%
lifeexp_df_Total.set_index('Country', inplace=True)
lifeexp_df_Total.sort_values('Country')
# Out:
#                                 YR1960     YR1961     YR1962     YR1963  \
# Country
# Afghanistan                  32.446000  32.962000  33.471000  33.971000
# Africa Eastern and Southern  42.716053  43.166935  43.603990  44.025617
# Africa Western and Central   37.205380  37.632546  38.052612  38.463746
# Albania                      62.283000  63.301000  64.190000  64.914000
# Algeria                      46.141000  46.599000  47.056000  47.509000
# ...                                ...        ...        ...        ...
# West Bank and Gaza                 NaN        NaN        NaN        NaN
# World                        52.581916  53.075105  53.492420  54.017514
# Yemen, Rep.                  29.919000  30.163000  30.500000  30.943000
# Zambia                       46.687000  47.084000  47.446000  47.772000
# Zimbabwe                     53.019000  53.483000  53.946000  54.403000
#
#                                 YR1964     YR1965     YR1966     YR1967  \
# Country
# ...

# %%
lifeexp_Uru_c = lifeexp_df_Total.loc[['Uruguay','New Zealand','Argentina','Belgium','Paraguay']]
lifeexp_Uru_c
# Out:
#                 YR1960     YR1961     YR1962     YR1963     YR1964     YR1965  \
# Country
# Uruguay      67.783000  68.007000  68.198000  68.347000  68.455000  68.521000
# New Zealand  71.236585  70.985366  71.231707  71.280488  71.329268  71.226829
# Argentina    65.055000  65.176000  65.269000  65.348000  65.426000  65.518000
# Belgium      69.701951  70.520976  70.219512  70.051463  70.755122  70.625366
# Paraguay     63.881000  64.105000  64.314000  64.500000  64.659000  64.793000
#
#                 YR1966     YR1967     YR1968     YR1969  ...     YR2012  \
# Country                                                  ...
# Uruguay      68.554000  68.567000  68.575000  68.588000  ...  77.004000
# New Zealand  71.124390  71.473171  71.124390  71.473171  ...  81.156098
# Argentina    65.640000  65.796000  65.989000  66.219000  ...  75.598000
# Belgium      70.706341  71.012927  70.693171  70.764878  ...  80.385366
# ...

# %%
lifeexp_Uru_c.set_index('Country', inplace=True)
lifeexp_Uru_c.sort_values('Country')

# %%
lifeexp_Uru = lifeexp_df_Total.loc['Uruguay']
lifeexp_Uru
# Out:
# YR1960    67.783
# YR1961    68.007
# YR1962    68.198
# YR1963    68.347
# YR1964    68.455
#            ...
# YR2017    77.632
# YR2018    77.770
# YR2019    77.911
# YR2020    78.056
# YR2021       NaN
# Name: Uruguay, Length: 62, dtype: float64

# %%
lifeexp_Uru.info() #es una serie
# Out:
# <class 'pandas.core.series.Series'>
# Index: 62 entries, YR1960 to YR2021
# Series name: Uruguay
# Non-Null Count  Dtype
# --------------  -----
# 61 non-null     float64
# dtypes: float64(1)
# memory usage: 3.0+ KB

# %%
L_exp_Uru = pd.DataFrame(lifeexp_Uru)

# %%
L_exp_Uru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, YR1960 to YR2021
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Uruguay  61 non-null     float64
# dtypes: float64(1)
# memory usage: 3.0+ KB

# %%
L_exp_Uru.columns
# Out:
# Index(['Uruguay'], dtype='object')

# %%
L_exp_Uru.plot.line()
# Out:
# <AxesSubplot:>

# %%
L_exp_Uru_c = pd.DataFrame(data= lifeexp_Uru_c, index=[['Uruguay','New Zealand','Argentina','Belgium','Paraguay']])
L_exp_Uru_c

# %%
L_exp_Uru_c

# %%
lifeexp_comp = lifeexp_Uru_c.loc[['Uruguay','Argentina']]
lifeexp_comp
# Out:
#            YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# Country
# Uruguay    67.783  68.007  68.198  68.347  68.455  68.521  68.554  68.567
# Argentina  65.055  65.176  65.269  65.348  65.426  65.518  65.640  65.796
#
#            YR1968  YR1969  ...  YR2012  YR2013  YR2014  YR2015  YR2016  \
# Country                    ...
# Uruguay    68.575  68.588  ...  77.004  77.124  77.244  77.369  77.498
# Argentina  65.989  66.219  ...  75.598  75.756  75.913  76.068  76.221
#
#            YR2017  YR2018  YR2019  YR2020  YR2021
# Country
# Uruguay    77.632   77.77  77.911  78.056     NaN
# Argentina  76.372   76.52  76.667  76.813     NaN
#
# [2 rows x 62 columns]

# %%
plt.figure(figsize=(15,10))
lifeexp_df_Total.loc['Uruguay'].plot.line()
lifeexp_df_Total.loc['Argentina'].plot.line()
lifeexp_df_Total.loc['New Zealand'].plot.line()
lifeexp_df_Total.loc['Belgium'].plot.line()
lifeexp_df_Total.loc['Paraguay'].plot.line()
lifeexp_df_Total.loc['World'].plot.line()
plt.legend()
